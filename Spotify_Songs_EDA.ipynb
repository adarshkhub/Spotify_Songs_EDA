# %%
# import libraries
import plotly.express as px
import pandas as pd
import seaborn as sns
sns.set(style='darkgrid')
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objects as go
import numpy as np

# %%
df = pd.read_csv("sample_data/data.csv")
df.head()
# Out:
#    Position                  Track Name         Artist  Streams  \
# 0         1  Reggaetón Lento (Bailemos)           CNCO    19272
# 1         2                    Chantaje        Shakira    19270
# 2         3   Otra Vez (feat. J Balvin)  Zion & Lennox    15761
# 3         4                Vente Pa' Ca   Ricky Martin    14954
# 4         5                      Safari       J Balvin    14269
#
#                                                  URL        Date Region
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# 2  https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01     ec
# 3  https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01     ec
# 4  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01     ec

# %%
featuresdf = pd.read_csv("sample_data/featuresdf.csv")
featuresdf.head()
# Out:
#                       id                                name  \
# 0  7qiZfU4dY1lWllzX7mPBI                        Shape of You
# 1  5CtI0qwDJkDQGwXD1H1cL                   Despacito - Remix
# 2  4aWmUDTfIPGksMNLV2rQP  Despacito (Featuring Daddy Yankee)
# 3  6RUKPb4LETWmmr3iAEQkt            Something Just Like This
# 4  3DXncPQOG4VBw3QHh3S81                         I'm the One
#
#             artists  danceability  energy   key  loudness  mode  speechiness  \
# 0        Ed Sheeran         0.825   0.652   1.0    -3.183   0.0       0.0802
# 1        Luis Fonsi         0.694   0.815   2.0    -4.328   1.0       0.1200
# 2        Luis Fonsi         0.660   0.786   2.0    -4.757   1.0       0.1700
# 3  The Chainsmokers         0.617   0.635  11.0    -6.769   0.0       0.0317
# 4         DJ Khaled         0.609   0.668   7.0    -4.284   1.0       0.0367
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %% [markdown]
# Find the number of days a US track has stayed in the 1st position for both the US and worldwide rankings on the same day. Output the track name and the number of days in the 1st position. Order your output alphabetically by track name.
#
#
# If the region 'US' appears in dataset, it should be included in the worldwide ranking.

# %%
featuresdf.sort_values(by=['energy'], ascending=False)
# Out:
#                        id                                    name  \
# 77  3EmmCZoqpWOTY1g2GBwJo                            Just Hold On
# 26  0afhq8XCExXpqazXczTSv                             Galway Girl
# 56  1NDxZ7cFAo481dtYWdrUn  Pretty Girl - Cheat Codes X CADE Remix
# 68  2cnKEkpVUSV4wnjQiTWfH                        Escápate Conmigo
# 96  0QsvXIfqM0zZoerQfsI9l                       Don't Let Me Down
# ..                    ...                                     ...
# 25  6D0b04NJIKfEMg040WioJ                                  Issues
# 67  38yBBH2jacvDxrznF7h08                              Slow Hands
# 76  1mXVgsBdtIVeCLJnSnmtd                    Too Good At Goodbyes
# 58  3kxfsdsCpFgN412fpnW85                                 Redbone
# 94  2fQrGHiQOvpL9UgPvtYy6                            Bank Account
#
#              artists  danceability  energy   key  loudness  mode  speechiness  \
# 77        Steve Aoki         0.647   0.932  11.0    -3.515   1.0       0.0824
# ...

# %%
featuresdf.sort_values(by=['danceability'], ascending=False)
# Out:
#                        id                                 name  \
# 48  4Km5HrUvYTaSUfiSGPJeQ  Bad and Boujee (feat. Lil Uzi Vert)
# 51  343YBumqHu19cGoGARUTs                            Fake Love
# 5   7KXjTSCq5nL1LoYtL7XAw                              HUMBLE.
# 42  5bcTCxgc7xVfSaMV3RuVk                                Feels
# 94  2fQrGHiQOvpL9UgPvtYy6                         Bank Account
# ..                    ...                                  ...
# 17  6PCUP3dWmTjcTtXY02oFd                   Castle on the Hill
# 63  6520aj0B4FSKGVuKNsOCO                Chained To The Rhythm
# 22  5uCax9HTNlzGybIStD3vD                 Say You Won't Let Go
# 66  5hYTyyh2odQKphUbMqc5g       How Far I'll Go - From "Moana"
# 99  1j4kHkkpqZRBwE0A4CN4Y          Dusk Till Dawn - Radio Edit
#
#            artists  danceability  energy   key  loudness  mode  speechiness  \
# 48           Migos         0.927   0.665  11.0    -5.313   1.0       0.2440
# ...

# %%
featuresdf.sort_values(by=['key'], ascending=False)
# Out:
#                        id                                     name  \
# 99  1j4kHkkpqZRBwE0A4CN4Y              Dusk Till Dawn - Radio Edit
# 57  3m660poUr1chesgkkjQM7                          Sorry Not Sorry
# 48  4Km5HrUvYTaSUfiSGPJeQ      Bad and Boujee (feat. Lil Uzi Vert)
# 3   6RUKPb4LETWmmr3iAEQkt                 Something Just Like This
# 62  00lNx0OcTJrS3MKHcB80H           You Don't Know Me - Radio Edit
# ..                    ...                                      ...
# 29  1x5sYLZiu9r5E43kMlt9f            Symphony (feat. Zara Larsson)
# 6   3eR23VReFzcdmS7TYCrhC          It Ain't Me (with Selena Gomez)
# 79  0CokSRCu5hZgPxcZBaEzV             Glorious (feat. Skylar Grey)
# 41  78rIJddV4X0HkNAInEcYd  Call On Me - Ryan Riback Extended Remix
# 21  0tKcYR2II1VCQWT79i5Nr                                  Thunder
#
#              artists  danceability  energy   key  loudness  mode  speechiness  \
# 99              ZAYN         0.258   0.437  11.0    -6.593   0.0       0.0390
# ...

# %%
featuresdf.sort_values(by=['loudness'], ascending=False)
# Out:
#                        id                            name           artists  \
# 50  6HUnnBwYZqcED1eQztxMB                      Solo Dance     Martin Jensen
# 47  6mICuAdrwEjh6Y6lroV2K                        Chantaje           Shakira
# 81  3AEZUABDXNtecAOSC1qTf      Reggaetón Lento (Bailemos)              CNCO
# 75  7vGuf3Y35N4wmASOKLUVV                         Silence        Marshmello
# 32  1OAh8uOEOvTDqkKFsKksC                   Wild Thoughts         DJ Khaled
# ..                    ...                             ...               ...
# 51  343YBumqHu19cGoGARUTs                       Fake Love             Drake
# 66  5hYTyyh2odQKphUbMqc5g  How Far I'll Go - From "Moana"      Alessia Cara
# 58  3kxfsdsCpFgN412fpnW85                         Redbone  Childish Gambino
# 36  7hDc8b7IXETo14hHIHdnh                    Passionfruit             Drake
# 46  152lZdxL1OR0ZMW6KquMi                        Location            Khalid
#
# ...

# %%
featuresdf.sort_values(by=['speechiness'], ascending=False)
# Out:
#                        id                                    name  \
# 14  0VgkVdmE4gld66l8iyGjg                                Mask Off
# 46  152lZdxL1OR0ZMW6KquMi                                Location
# 51  343YBumqHu19cGoGARUTs                               Fake Love
# 66  5hYTyyh2odQKphUbMqc5g          How Far I'll Go - From "Moana"
# 60  6HZILIRieu8S0iqY8kIKh                                    DNA.
# ..                    ...                                     ...
# 70  5Ohxk2dO5COHF1krpoPig                       Sign of the Times
# 49  0ofbQMrRDsUaVKq2mGLEA                                  Havana
# 11  72jbDTw1piOOj770jWNea                                   Paris
# 56  1NDxZ7cFAo481dtYWdrUn  Pretty Girl - Cheat Codes X CADE Remix
# 40  0tgVpDi06FyKpA1z0VMD4                                 Perfect
#
#              artists  danceability  energy  key  loudness  mode  speechiness  \
# 14            Future         0.833   0.434  2.0    -8.795   1.0       0.4310
# ...

# %%
featuresdf.sort_values(by=['acousticness'], ascending=False)
# Out:
#                        id                  name         artists  danceability  \
# 22  5uCax9HTNlzGybIStD3vD  Say You Won't Let Go    James Arthur         0.358
# 76  1mXVgsBdtIVeCLJnSnmtd  Too Good At Goodbyes       Sam Smith         0.698
# 90  1a5Yu5L18qNxVhXx38njO           Hear Me Now            Alok         0.789
# 0   7qiZfU4dY1lWllzX7mPBI          Shape of You      Ed Sheeran         0.825
# 35  5tz69p7tJuGPeMGwNTxYu        1-800-273-8255           Logic         0.629
# ..                    ...                   ...             ...           ...
# 77  3EmmCZoqpWOTY1g2GBwJo          Just Hold On      Steve Aoki         0.647
# 89  4b4KcovePX8Ke2cLIQTLM             All Night       The Vamps         0.544
# 10  7GX5flRQZVHRAGd6B4TmD         XO TOUR Llif3    Lil Uzi Vert         0.732
# 34  2ekn2ttSfGqwhhate0LSR             New Rules        Dua Lipa         0.771
# 5   7KXjTSCq5nL1LoYtL7XAw               HUMBLE.  Kendrick Lamar         0.904
#
# ...

# %%
featuresdf.sort_values(by=['tempo'], ascending=False)
# Out:
#                        id                         name     artists  \
# 52  4pdPtRcBmOSQDlJ3Fk945              Let Me Love You    DJ Snake
# 63  6520aj0B4FSKGVuKNsOCO        Chained To The Rhythm  Katy Perry
# 31  5aAx2yezTd8zXrkmtKl66                      Starboy  The Weeknd
# 99  1j4kHkkpqZRBwE0A4CN4Y  Dusk Till Dawn - Radio Edit        ZAYN
# 61  3umS4y3uQDkqekNjVpiRU                    El Amante   Nicky Jam
# ..                    ...                          ...         ...
# 69  0SGkqnVQo9KPytSri1H6c                  Bounce Back    Big Sean
# 4   3DXncPQOG4VBw3QHh3S81                  I'm the One   DJ Khaled
# 46  152lZdxL1OR0ZMW6KquMi                     Location      Khalid
# 45  2EEeOnHehOozLq4aS0n6S      iSpy (feat. Lil Yachty)        KYLE
# 94  2fQrGHiQOvpL9UgPvtYy6                 Bank Account   21 Savage
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 52         0.476   0.718   8.0    -5.309   1.0       0.0576        0.0784
# ...
